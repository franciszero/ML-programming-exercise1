# %% [markdown]
# # Introduction to classes and objects in Python

# %% [markdown]
# # Defining class in Python

# %%
class Person:
    "This is a person class"
    age = 10
    name = 'Garima'

    def greet(self):
        print('Hello')


# Output: 10
print(Person.age)

# Output: <function Person.greet>
print(Person.greet)

# Output: 'This is my second class'
print(Person.__doc__)
# Out:
# 10
# <function Person.greet at 0x7f7d3289cf80>
# This is a person class

# %%
p1 = Person()
p2 = Person()

# %%
p1.greet()
# Out:
# Hello

# %% [markdown]
# # Creating object in Python

# %%
class Person:
    "This is a person class"
    age = 10

    def greet(self):
        print('Hello')


# create a new object of Person class
harry = Person()

# Output: <function Person.greet>
print(Person.greet)

# Output: <bound method Person.greet of <__main__.Person object>>
print(harry.greet())

# Calling object's greet() method
# Output: Hello
harry.greet()
# Out:
# <function Person.greet at 0x7fd28ae53950>
# Hello
# None
# Hello

# %% [markdown]
# # self and __init__ in Python

# %%
class Cat:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def info(self):
        print(f"I am a cat. My name is {self.name}. I am {self.age} years old.")

    def make_sound(self):
        print("Meow")

# %%
cat1 = Cat('Andy', 2)
cat2 = Cat('Phoebe', 3)

# %%
cat1.info()
# Out:
# I am a cat. My name is Andy. I am 2 years old.

# %%
cat2.info()
# Out:
# I am a cat. My name is Phoebe. I am 3 years old.

# %%
class Student:
  def __init__(self, s_rollno, s_marks):
    self.s_name = 'Garima'
    self.s_rollno = s_rollno
    self.s_marks = s_marks
  def change_name(self,name):
    self.s_name = name

  def print_info(self):
    print("Student Info :", self.s_name,self.s_rollno,self.s_marks)
  
  def average(self):
    print("The average of studnet marks is :", sum(self.s_marks)/len(self.s_marks))

# %%
S3 = Student('garima',103,[90,78,90])

# %%
S3.change_name

# %%
S1 = Student('minje',101,[90,80,90])
S2 = Student('pan',102,[90,79,89])

# %%
S1.print_info()
# Out:
# Student Info : minje 101 [90, 80, 90]

# %%
S1.average()
# Out:
# The average of studnet marks is : 86.66666666666667

# %%
class Bank:
  def __init__():
    pass
  def cal_bill():
    pass

# %%
c1 = Bank()
c2 = Bank()
c3 = Bank()
